# %%
import pandas as pd

# %%
victims = pd.read_excel('Victims_Age_by_Offense_Category_2022.xlsx')
victims
# Out:
#                                               Victims       Unnamed: 1  \
# 0                                                 Age              NaN
# 1                           by Offense Category, 2022              NaN
# 2                                    Offense Category  Total\nVictims1
# 3                                                 NaN              NaN
# 4                                               Total          9715061
# 5                              Crimes Against Persons          3456189
# 6                                    Assault Offenses          3187575
# 7                                   Homicide Offenses            18785
# 8                          Human Trafficking Offenses             2691
# 9                                Kidnapping/Abduction            43083
# 10                                       Sex Offenses           204055
# 11                            Crimes Against Property          6258872
# 12                                              Arson            22853
# 13                                            Bribery              515
# 14                       Burglary/Breaking & Entering           578164
# 15                             Counterfeiting/Forgery            78480
# 16                       Destruction/Damage/Vandalism          1225891
# 17                                       Embezzlement             8800
# 18                                Extortion/Blackmail            20608
# 19                                     Fraud Offenses           753459
# 20                             Larceny/Theft Offenses          2619852
# 21                                Motor Vehicle Theft           676806
# 22                                            Robbery           168132
# 23                           Stolen Property Offenses           105312
# 24  1This table includes only data for the victim ...              NaN
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2            Age         NaN        NaN        NaN        NaN        NaN
# 3   10 and\nUnder      11−15      16−20      21−25      26−30      31−35
# 4          161808     313727     642246    1055358    1136941    1132001
# 5          145725     272605     346638     420370     436189     423128
# 6          104040     210017     300568     393342     414940     404453
# 7             702        473       2468       2597       2534       2332
# 8             102        588        712        338        228        185
# 9            4289       2627       4797       6442       6088       5526
# 10          36592      58900      38093      17651      12399      10632
# 11          16083      41122     295608     634988     700752     708873
# 12            484        318        663       1293       1804       2334
# 13              9         26         60         72         73         77
# 14           2591       2927      19887      49849      59183      63094
# 15            112        111       1712       3184       4132       5060
# 16           2588       4258      56076     128389     143014     144377
# 17              9         16        197        372        608        708
# 18             45       1905       6851       3528       1693       1288
# 19           1196       1953      29350      55682      64905      72015
# 20           5496      23094     136566     290201     307962     304299
# 21            686        401      21719      68745      84499      84716
# 22            946       5684      18748      24492      22166      19905
# 23           1921        429       3779       9181      10713      11000
# 24            NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         NaN        NaN         NaN         NaN         NaN         NaN
# 2         NaN        NaN         NaN         NaN         NaN         NaN
# 3       36−40      41−45       46−50       51−55       56−60       61−65
# 4     1001060     848189      703884      654694      598804      479802
# 5      354483     277881      207148      175579      143857       96851
# 6      339714     267251      199850      170264      139937       94304
# 7        1847       1427        1062         874         744         570
# 8         144         83          47          36          24           3
# 9        4346       3078        1950        1397         903         543
# 10       8432       6042        4239        3008        2249        1431
# 11     646577     570308      496736      479115      454947      382951
# 12       2356       2244        2084        1776        1999        1456
# 13         39         41          36          14          13           7
# 14      59799      53449       47653       47088       46526       40424
# 15       5580       5791        5963        6679        7360        7672
# 16     133341     117317      100164       95536       88137       73399
# 17        791        828         722         805         778         733
# 18       1058        908         750         635         520         478
# 19      69125      64000       59469       59908       59842       56632
# 20     271791     235848      202782      194738      182275      151457
# 21      76015      67503       57863       54781       50673       38768
# 22      16809      13751       11017        9925        9107        6649
# 23       9873       8628        8233        7230        7717        5276
# 24        NaN        NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 14   Unnamed: 15
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3   66 and\nOver  Unknown\nAge
# 4         835611        150936
# 5         113436         42299
# 6         109263         39632
# 7            945           210
# 8             11           190
# 9            782           315
# 10          2435          1952
# 11        722175        108637
# 12          2731          1311
# 13            11            37
# 14         77290          8404
# 15         22337          2787
# 16        119564         19731
# 17          1952           281
# 18           852            97
# 19        145392         13990
# 20        274957         38386
# 21         60149         10288
# 22          7675          1258
# 23          9265         12067
# 24           NaN           NaN

# %%
# Elimino las primeras
victims.drop(victims.index[:2], inplace=True)
victims.drop(victims.index[-1], inplace=True)

# %%
# Genero el indice que voy a utilizar mas adelante para acomodar la informacion.
indice_age = victims.iloc[1].values[2:]
indice_age = [x for x in indice_age]
indice_age.insert(0,'Total_Victims')
indice_age.insert(0,'Offense Category')
indice_age = [columna.replace('\n', ' ') if isinstance(columna, str) else columna for columna in indice_age]
indice_age
# Out:
# ['Offense Category',
#  'Total_Victims',
#  '10 and Under',
#  '11−15',
#  '16−20',
#  '21−25',
#  '26−30',
#  '31−35',
#  '36−40',
#  '41−45',
#  '46−50',
#  '51−55',
#  '56−60',
#  '61−65',
#  '66 and Over',
#  'Unknown Age']

# %%
# Genero Nuevo Dataframe con la categoria indicada
Crimes_Against_Property = victims.loc[victims['Victims'] == 'Crimes Against Property'].copy()
Crimes_Against_Property.columns = indice_age[0:len(Crimes_Against_Property.columns)]
Crimes_Against_Property.drop(columns=['Total_Victims'], inplace=True)

# %%
# Transformo el Dataframe
Crimes_Against_Property = Crimes_Against_Property.transpose()

# %%
# ultimo paso para limpiar y reacomodar el Dataframe
Crimes_Against_Property.drop(Crimes_Against_Property.index[0], inplace=True)
Crimes_Against_Property.columns = ['Crimes Against Property']
Crimes_Against_Property = Crimes_Against_Property.rename_axis('Age')
Crimes_Against_Property
# Out:
#              Crimes Against Property
# Age
# 10 and Under                   16083
# 11−15                          41122
# 16−20                         295608
# 21−25                         634988
# 26−30                         700752
# 31−35                         708873
# 36−40                         646577
# 41−45                         570308
# 46−50                         496736
# 51−55                         479115
# 56−60                         454947
# 61−65                         382951
# 66 and Over                   722175
# Unknown Age                   108637

# %%
# Exporto el archivo .csv
Crimes_Against_Property.to_csv('Crimes_Against_Property.csv')
